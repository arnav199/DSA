# %%
class node:
    def __init__(self, data=None, next=None):
        self.value = data
        self.next = next

class linkedlist:
      def __init__(self, head=None):
           self.head = head
           def insert_at_beginning(self, data):
                new_node = node(data, self.head)
                self.head = new_node

                insert_at_beginning(5)

                def insert_at_end(self, data):
                     new_node = node(data)
                     if self.head is None:
                         self.head = new_node
                     temp = self.head
                     while temp.next:
                         temp = temp.next
                     temp.next = new_node

                     def display(self):
                          temp = self.head
                          while temp:
                              print(temp.value, end=' ')
                              temp = temp.next

                          print("None")
                          def insert_at_position(self, val, data):
                                 temp = self.head
                                 while temp.next and temp.value != val:
                                      temp = temp.next
